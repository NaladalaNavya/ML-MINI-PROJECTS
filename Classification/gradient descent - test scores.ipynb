# %% [markdown]
# <img src="https://cdn.educba.com/academy/wp-content/uploads/2023/03/Gradient-Descent-of-Machine-Learning.jpg" style="width:400px;height:200px;">
# <h1 color="blue">Gradient Descent on test scores</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import math
df=pd.read_csv(r"C:\Users\Bezawada\Downloads\test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
def predict_using_sklean():
    df = pd.read_csv(r"C:\Users\Bezawada\Downloads\test_scores.csv")
    r = LinearRegression()
    r.fit(df[['math']],df.cs)
    return r.coef_, r.intercept_

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr = 0
    b_curr = 0
    iterations = 100000
    n = len(x)
    learning_rate = 0.0002
    cost_previous = 0
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        plt.plot(x,y_predicted, color="green")
        cost = (1/n)*sum([value**2 for value in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
        cost_previous = cost
        #print ("m= {}, b= {}, cost= {}, iteration ={}".format(m_curr,b_curr,cost, i))
    return m_curr,b_curr

# %%
if __name__ == "__main__":
    df = pd.read_csv(r"C:\Users\Bezawada\Downloads\test_scores.csv")
    x = np.array(df.math)
    y = np.array(df.cs)

    m, b = gradient_descent(x,y)
    print("Using gradient descent function: Coef {} Intercept {}".format(m, b))

    m_sklearn, b_sklearn = predict_using_sklean()
    print("Using sklearn: Coef {} Intercept {}".format(m_sklearn,b_sklearn))
# Out:
# Using gradient descent function: Coef 1.0204362110820604 Intercept 1.72387921708579
# Using sklearn: Coef [1.01773624] Intercept 1.9152193111568891
